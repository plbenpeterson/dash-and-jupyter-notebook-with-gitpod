# %% [markdown]
# # Efficient Frontier

# %%
import pandas as pd
ind = pd.read_csv("data/ind30_m_vw_rets.csv", header=0, index_col=0, parse_dates=True)/100

# %%
ind.head()
# Out:
#          Food    Beer    Smoke   Games   Books   Hshld   Clths   Hlth   \
# 192607  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 192608  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 192609  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 192610 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 192611  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#          Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 192607  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 192608  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 192609  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 192610 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 192611  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#          Rtail   Meals   Fin     Other
# 192607  0.0007  0.0187  0.0037  0.0520
# ...

# %%
ind.index
# Out:
# Int64Index([192607, 192608, 192609, 192610, 192611, 192612, 192701, 192702,
#             192703, 192704,
#             ...
#             201803, 201804, 201805, 201806, 201807, 201808, 201809, 201810,
#             201811, 201812],
#            dtype='int64', length=1110)

# %%
ind.index = pd.to_datetime(ind.index, format="%Y%m").to_period('M')

# %%
ind.index
# Out:
# PeriodIndex(['1926-07', '1926-08', '1926-09', '1926-10', '1926-11', '1926-12',
#              '1927-01', '1927-02', '1927-03', '1927-04',
#              ...
#              '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08',
#              '2018-09', '2018-10', '2018-11', '2018-12'],
#             dtype='period[M]', length=1110, freq='M')

# %%
ind.head()
# Out:
#           Food    Beer    Smoke   Games   Books   Hshld   Clths   Hlth   \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#           Rtail   Meals   Fin     Other
# ...

# %%
ind.columns
# Out:
# Index(['Food ', 'Beer ', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth ',
#        'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
#        'Mines', 'Coal ', 'Oil  ', 'Util ', 'Telcm', 'Servs', 'BusEq', 'Paper',
#        'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin  ', 'Other'],
#       dtype='object')

# %%
ind["Food "].shape
# Out:
# (1110,)

# %% [markdown]
# # This is a problem above, the columns have a space in them. Let's fix

# %%
ind.columns = ind.columns.str.strip()

# %%
ind.columns
# Out:
# Index(['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth',
#        'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
#        'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper',
#        'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other'],
#       dtype='object')

# %%
ind.shape
# Out:
# (1110, 30)

# %%
# %load_ext autoreload
# %autoreload 2
import edhec_risk_kit as erk

# %%
ind = erk.get_ind_returns()

# %%
ind.shape
# Out:
# (1110, 30)

# %%
ind.head()
# Out:
#            Food    Beer   Smoke   Games   Books   Hshld   Clths    Hlth  \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#           Rtail   Meals     Fin   Other
# ...

# %%
erk.drawdown(ind["Food"])["Drawdown"].plot.line(12, 6)
# Out:
# <AxesSubplot:>

# %%
ind[["Smoke", "Beer"]]
# Out:
#           Smoke    Beer
# 1926-07  0.0129 -0.0519
# 1926-08  0.0650  0.2703
# 1926-09  0.0126  0.0402
# 1926-10  0.0106 -0.0331
# 1926-11  0.0455  0.0729
# ...         ...     ...
# 2018-08 -0.0543 -0.0186
# 2018-09  0.0537  0.0019
# 2018-10  0.0790 -0.0157
# 2018-11 -0.0843  0.0579
# 2018-12 -0.1580 -0.0969
#
# [1110 rows x 2 columns]

# %%
erk.var_gaussian(ind[["Food", "Beer", "Smoke", "Coal", "Fin"]],modified=True)
# Out:
# Food     0.061233
# Beer     0.089617
# Smoke    0.080293
# Coal     0.163931
# Fin      0.079673
# dtype: float64

# %%
erk.var_gaussian(ind, modified=True).sort_values().plot.bar()
# Out:
# <AxesSubplot:>

# %%
erk.sharpe_ratio(ind, 0.03, 12).sort_values().plot.bar(title="Industry Sharpe Ratios 1926-2018", color="green")
# Out:
# <AxesSubplot:title={'center':'Industry Sharpe Ratios 1926-2018'}>

# %%
erk.sharpe_ratio(ind["2000":], 0.03, 12).sort_values().plot.bar(title="Industry Sharpe Ratios 2000-2018", figsize=(12,5), color="goldenrod")
# Out:
# <AxesSubplot:title={'center':'Industry Sharpe Ratios 2000-2018'}>

# %%
er = erk.annualize_rets(ind["1995":"2000"], 12)

# %% [raw]
# er.sort_values().plot.bar()

# %%
cov = ind["1995":"2000"].cov()

# %%
cov
# Out:
#            Food      Beer     Smoke     Games     Books     Hshld     Clths  \
# Food   0.002287  0.002077  0.001757  0.000701  0.000886  0.001208  0.001474
# Beer   0.002077  0.004599  0.001143  0.001147  0.000765  0.002447  0.001415
# Smoke  0.001757  0.001143  0.007130  0.000296 -0.000099  0.000981  0.000761
# Games  0.000701  0.001147  0.000296  0.003271  0.001485  0.001018  0.001814
# Books  0.000886  0.000765 -0.000099  0.001485  0.002302  0.000876  0.002037
# Hshld  0.001208  0.002447  0.000981  0.001018  0.000876  0.002849  0.001046
# Clths  0.001474  0.001415  0.000761  0.001814  0.002037  0.001046  0.004896
# Hlth   0.001105  0.001689  0.000877  0.001219  0.000657  0.001253  0.000759
# Chems  0.001253  0.001292  0.000687  0.001547  0.001559  0.001226  0.002547
# Txtls  0.001021  0.001721  0.000555  0.001291  0.001362  0.001172  0.002105
# Cnstr  0.001282  0.001945  0.001181  0.001723  0.001531  0.001770  0.002486
# ...

# %% [markdown]
# # A covariance matrix is a square matrix that has as many rows/columns as assets

# %% [markdown]
# # Applying Quaprog to the efficient frontier
# you need the expressions for the RETURN and VOLATILITY of a given portfolio
# The returns of a given portfolio with 2 assets depend ONLY on the weights of those assets.
# The volatility of a given portfolio with 2 assets depends on the correlation between those two assets. More exactly, the volatility of a given portfolio is a function of the COVARIANCES between each pair of assets, which in turn depends on the volatilities and correlations of the assets.
# It can be referred to as the variance-covariance matrix because the diagonals are just the variances.
# You want to minimize volatility for a certain level of return.
# Quadratic Form is what you want to hand to a quadratic optimizer.

# %%
ind = erk.get_ind_returns()
er = erk.annualize_rets(ind["1996":"2000"], 12)
cov = ind["1996":"2000"].cov()

# %%
def portfolio_return(weights, returns):
    """
    Weights -> Returns
    """
    return weights.T @ returns

def portfolio_vol(weights, covman):
    """
    Weights -> Volatility
    """
    return (weights.T @ covmat @ weights)**0.5

# %%
l = ["Food", "Beer", "Smoke", "Coal"]
er[l]
# Out:
# Food     0.116799
# Beer     0.141126
# Smoke    0.107830
# Coal     0.414689
# dtype: float64

# %%
cov.loc[l, l]
# Out:
#            Food      Beer     Smoke      Coal
# Food   0.002609  0.002379  0.002061  0.000027
# Beer   0.002379  0.005264  0.001359  0.001728
# Smoke  0.002061  0.001359  0.008349 -0.000733
# Coal   0.000027  0.001728 -0.000733  0.018641

# %%
import numpy as np
weights = np.repeat(1/4, 4)
weights
# Out:
# array([0.25, 0.25, 0.25, 0.25])

# %%
erk.portfolio_return(weights, er[l])
# Out:
# 0.19511097196038385

# %%
erk.portfolio_vol(weights, cov.loc[l,l])
# Out:
# 0.055059195776437045

# %% [markdown]
# # 2 Asset Frontier

# %%
l = ["Games", "Fin"]

# %%
n_points = 20
weights = [np.array([w, 1-w]) for w in np.linspace(0, 1, n_points)]
weights
# Out:
# [array([0., 1.]),
#  array([0.05263158, 0.94736842]),
#  array([0.10526316, 0.89473684]),
#  array([0.15789474, 0.84210526]),
#  array([0.21052632, 0.78947368]),
#  array([0.26315789, 0.73684211]),
#  array([0.31578947, 0.68421053]),
#  array([0.36842105, 0.63157895]),
#  array([0.42105263, 0.57894737]),
#  array([0.47368421, 0.52631579]),
#  array([0.52631579, 0.47368421]),
#  array([0.57894737, 0.42105263]),
#  array([0.63157895, 0.36842105]),
#  array([0.68421053, 0.31578947]),
#  array([0.73684211, 0.26315789]),
#  array([0.78947368, 0.21052632]),
#  array([0.84210526, 0.15789474]),
#  array([0.89473684, 0.10526316]),
#  array([0.94736842, 0.05263158]),
#  array([1., 0.])]

# %%
len(weights)
# Out:
# 20

# %%
l
# Out:
# ['Games', 'Fin']

# %%
rets = [erk.portfolio_return(w, er[l]) for w in weights]
vols = [erk.portfolio_return(w, cov.loc[l,l]) for w in weights]
ef = pd.DataFrame({"R": rets, "Vol": vols})
ef.plot.line(x="Vol", y="R", style=".-")
# Out:
# <AxesSubplot:xlabel='Vol'>

# %%
l = ["Fin", "Beer"]
erk.plot_ef2(25, er[l], cov.loc[l,l])
# Out:
# <AxesSubplot:xlabel='Volatility'>
